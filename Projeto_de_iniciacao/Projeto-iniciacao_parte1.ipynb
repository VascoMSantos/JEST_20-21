# %% [markdown]
# # Classificar Pulse stars

# %% [markdown]
# ### SETUP

# %%
import pandas as pd
import seaborn as sns
pd.plotting.register_matplotlib_converters()
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ### IMPORTAR OS DADOS

# %%
# No ficheiro csv que está no GitHub, tirar o url do "raw"
path_file = 'https://raw.githubusercontent.com/spingegod/ProjetoTI_part1/master/ProjetoTI/pulsar_stars.csv'

df = pd.read_csv(path_file)

df
# Out:
#         Mean of the integrated profile  \
# 0                           140.562500
# 1                           102.507812
# 2                           103.015625
# 3                           136.750000
# 4                            88.726562
# ...                                ...
# 17893                       136.429688
# 17894                       122.554688
# 17895                       119.335938
# 17896                       114.507812
# 17897                        57.062500
#
#         Standard deviation of the integrated profile  \
# 0                                          55.683782
# 1                                          58.882430
# 2                                          39.341649
# 3                                          57.178449
# 4                                          40.672225
# ...                                              ...
# 17893                                      59.847421
# 17894                                      49.485605
# ...

# %% [markdown]
# ### Visualization

# %%
df.describe()
# Out:
#         Mean of the integrated profile  \
# count                     17898.000000
# mean                        111.079968
# std                          25.652935
# min                           5.812500
# 25%                         100.929688
# 50%                         115.078125
# 75%                         127.085938
# max                         192.617188
#
#         Standard deviation of the integrated profile  \
# count                                   17898.000000
# mean                                       46.549532
# std                                         6.843189
# min                                        24.772042
# 25%                                        42.376018
# 50%                                        46.947479
# 75%                                        51.023202
# max                                        98.778911
#
#         Excess kurtosis of the integrated profile  \
# count                                17898.000000
# ...

# %%
# Correlation matrix
corrMatrix = df.corr()

plt.figure(figsize=(15,10))

sns.heatmap(corrMatrix, annot=True)

# %% [markdown]
# ### Pre-processamento

# %%
# Sampling
